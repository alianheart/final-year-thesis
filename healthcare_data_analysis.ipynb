# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
file_path = 'healthcare_data.csv'
data = pd.read_csv('thesis/healthcare_data.csv')

# %%
# Display basic information about the dataset
print("Data Overview:")
print(data.info())
# Out:
# Data Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Patient_ID        1000 non-null   int64
#  1   Age               1000 non-null   int64
#  2   Gender            1000 non-null   object
#  3   Diagnosis_Code    1000 non-null   object
#  4   Treatment_Type    1000 non-null   object
#  5   Admission_Date    1000 non-null   object
#  6   Discharge_Date    1000 non-null   object
#  7   Length_of_Stay    1000 non-null   int64
#  8   Treatment_Cost    1000 non-null   float64
#  9   Readmission_Rate  1000 non-null   float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 78.2+ KB
# None

# %%
# Display the first few rows of the dataset
print("\nFirst few rows of the dataset:")
print(data.head())
# Out:
# First few rows of the dataset:
#    Patient_ID  Age  Gender Diagnosis_Code Treatment_Type Admission_Date  \
# 0           1   69    Male           D001        Surgery     2022-01-01
# 1           2   32    Male           D004    Observation     2022-01-02
# 2           3   89  Female           D002        Surgery     2022-01-03
# 3           4   78    Male           D001    Observation     2022-01-04
# 4           5   38    Male           D003     Medication     2022-01-05
#
#   Discharge_Date  Length_of_Stay  Treatment_Cost  Readmission_Rate
# 0     2022-01-09               8    28365.105685          0.701738
# 1     2022-01-09               7    32348.870739          0.556465
# 2     2022-01-07               4    16040.854137          0.358622
# 3     2022-01-06               2     7597.947165          0.911339
# 4     2022-01-08               3    22596.479111          0.020934

# %%
# Summary statistics
print("\nSummary statistics:")
print(data.describe())
# Out:
# Summary statistics:
#         Patient_ID          Age  Length_of_Stay  Treatment_Cost  \
# count  1000.000000  1000.000000     1000.000000     1000.000000
# mean    500.500000    52.881000        7.383000    27178.146986
# std     288.819436    20.958915        3.972164    12866.444196
# min       1.000000    18.000000        1.000000     5001.382348
# 25%     250.750000    34.750000        4.000000    15856.486711
# 50%     500.500000    52.500000        7.000000    27164.850158
# 75%     750.250000    71.000000       11.000000    38099.790814
# max    1000.000000    89.000000       14.000000    49980.096646
#
#        Readmission_Rate
# count       1000.000000
# mean           0.494554
# std            0.287067
# min            0.000227
# 25%            0.244974
# 50%            0.483831
# 75%            0.746063
# max            0.997749

# %%
# Check for missing values
print("\nMissing values in each column:")
print(data.isnull().sum())
# Out:
# Missing values in each column:
# Patient_ID          0
# Age                 0
# Gender              0
# Diagnosis_Code      0
# Treatment_Type      0
# Admission_Date      0
# Discharge_Date      0
# Length_of_Stay      0
# Treatment_Cost      0
# Readmission_Rate    0
# dtype: int64

# %%
# Data types of columns
print("\nData types of each column:")
print(data.dtypes)
# Out:
# Data types of each column:
# Patient_ID            int64
# Age                   int64
# Gender               object
# Diagnosis_Code       object
# Treatment_Type       object
# Admission_Date       object
# Discharge_Date       object
# Length_of_Stay        int64
# Treatment_Cost      float64
# Readmission_Rate    float64
# dtype: object

# %%
# Distribution of numerical features
print("\nDistribution of numerical features:")
data.hist(figsize=(14, 10), bins=30, edgecolor='black')
plt.tight_layout()
plt.show()
# Out:
# Distribution of numerical features:

# %%
# Pairplot for numerical features
print("\nPairplot of numerical features:")
sns.pairplot(data)
plt.show()
# Out:
# Pairplot of numerical features:

# %%
# Boxplot for treatment cost by treatment type
print("\nBoxplot of Treatment Cost by Treatment Type:")
plt.figure(figsize=(12, 6))
sns.boxplot(x='Treatment_Type', y='Treatment_Cost', data=data)
plt.xticks(rotation=45)
plt.title('Boxplot of Treatment Cost by Treatment Type')
plt.show()
# Out:
# Boxplot of Treatment Cost by Treatment Type:

# %%
# Distribution of Readmission Rate
print("\nDistribution of Readmission Rate:")
plt.figure(figsize=(10, 6))
sns.histplot(data['Readmission_Rate'], kde=True, bins=30)
plt.title('Distribution of Readmission Rate')
plt.show()
# Out:
# Distribution of Readmission Rate:

# %%
# Assuming 'data' is your DataFrame
print(data.info())  # Check data types
print(data.select_dtypes(include=['object']).columns)  # List non-numeric columns

# If you want to drop non-numeric columns
numeric_data = data.select_dtypes(include=[float, int])

# Alternatively, if you want to encode categorical columns
# For example, using one-hot encoding
data_encoded = pd.get_dummies(data, drop_first=True)
numeric_data = data_encoded.select_dtypes(include=[float, int])

# Calculate correlation matrix
correlation_matrix = numeric_data.corr()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Patient_ID        1000 non-null   int64
#  1   Age               1000 non-null   int64
#  2   Gender            1000 non-null   object
#  3   Diagnosis_Code    1000 non-null   object
#  4   Treatment_Type    1000 non-null   object
#  5   Admission_Date    1000 non-null   object
#  6   Discharge_Date    1000 non-null   object
#  7   Length_of_Stay    1000 non-null   int64
#  8   Treatment_Cost    1000 non-null   float64
#  9   Readmission_Rate  1000 non-null   float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 78.2+ KB
# None
# Index(['Gender', 'Diagnosis_Code', 'Treatment_Type', 'Admission_Date',
#        'Discharge_Date'],
#       dtype='object')

# %%
# Plot heatmap
print("\nCorrelation heatmap:")
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# Correlation heatmap:

# %%
# Countplot for Diagnosis Code
print("\nCountplot of Diagnosis Code:")
plt.figure(figsize=(12, 6))
sns.countplot(x='Diagnosis_Code', data=data)
plt.title('Count of Diagnosis Codes')
plt.show()
# Out:
# Countplot of Diagnosis Code:

# %%
# Countplot for Treatment Type
print("\nCountplot of Treatment Type:")
plt.figure(figsize=(12, 6))
sns.countplot(x='Treatment_Type', data=data)
plt.title('Count of Treatment Types')
plt.show()
# Out:
# Countplot of Treatment Type:

# %%
# Violin plot for Length of Stay by Diagnosis Code
print("\nViolin plot of Length of Stay by Diagnosis Code:")
plt.figure(figsize=(12, 6))
sns.violinplot(x='Diagnosis_Code', y='Length_of_Stay', data=data)
plt.title('Violin Plot of Length of Stay by Diagnosis Code')
plt.show()
# Out:
# Violin plot of Length of Stay by Diagnosis Code:

# %%
# Heatmap of missing values
print("\nHeatmap of Missing Values:")
plt.figure(figsize=(12, 6))
sns.heatmap(data.isnull(), cbar=False, cmap='viridis')
plt.title('Heatmap of Missing Values')
plt.show()
# Out:
# Heatmap of Missing Values:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_curve, roc_auc_score, precision_recall_curve

# %%
# Function to handle missing values
def handle_missing_values(df):
    """
    Handle missing values in the DataFrame.
    
    Parameters:
    df (pd.DataFrame): The DataFrame with missing values
    
    Returns:
    pd.DataFrame: DataFrame with missing values handled
    """
    # Fill missing values with median for numerical features
    for column in df.select_dtypes(include=[np.number]).columns:
        df[column].fillna(df[column].median(), inplace=True)
    
    # Fill missing values with the most frequent value for categorical features
    for column in df.select_dtypes(include=[object]).columns:
        df[column].fillna(df[column].mode()[0], inplace=True)
    
    return df

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Function to apply Linear Regression with extended features
def apply_linear_regression(df, target_column):
    """
    Applies Linear Regression to the DataFrame and evaluates the model.
    
    Parameters:
    df (pd.DataFrame): The DataFrame with features and target column
    target_column (str): The name of the target column
    
    Returns:
    None
    """
    # Copy the DataFrame to avoid modifying the original data
    df = df.copy()
    
    # Separate features and target
    X = df.drop(columns=[target_column])
    y = df[target_column]
    
    # Encode categorical variables
    X = pd.get_dummies(X, drop_first=True)
    
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    
    # Standardize the features
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    
    # Initialize and train the Linear Regression model
    model = LinearRegression()
    model.fit(X_train, y_train)
    
    # Make predictions
    y_pred = model.predict(X_test)
    
    # Evaluate the model
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    print("\nLinear Regression Model Evaluation:")
    print(f"Mean Squared Error: {mse:.4f}")
    print(f"R^2 Score: {r2:.4f}")
    
    # Plot predicted vs actual values
    plt.figure(figsize=(8, 6))
    plt.scatter(y_test, y_pred, alpha=0.5)
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title('Actual vs Predicted Values')
    plt.show()

# %%
# Load the data
file_path = 'thesis/healthcare_data.csv'
data = pd.read_csv(file_path)

# Handle missing values
data = handle_missing_values(data)

# Display basic information about the dataset
print("Data Overview:")
print(data.info())

# Display the first few rows of the dataset
print("\nFirst few rows of the dataset:")
print(data.head())

# Apply Linear Regression (assuming 'Readmission_Rate' is the target variable)
apply_linear_regression(data, 'Readmission_Rate')
# Out:
# Data Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Patient_ID        1000 non-null   int64
#  1   Age               1000 non-null   int64
#  2   Gender            1000 non-null   object
#  3   Diagnosis_Code    1000 non-null   object
#  4   Treatment_Type    1000 non-null   object
#  5   Admission_Date    1000 non-null   object
#  6   Discharge_Date    1000 non-null   object
#  7   Length_of_Stay    1000 non-null   int64
#  8   Treatment_Cost    1000 non-null   float64
#  9   Readmission_Rate  1000 non-null   float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 78.2+ KB
# None
#
# First few rows of the dataset:
#    Patient_ID  Age  Gender Diagnosis_Code Treatment_Type Admission_Date  \
# 0           1   69    Male           D001        Surgery     2022-01-01
# ...

# %%
# Convert continuous target to binary (e.g., high vs. low readmission rate)
def categorize_target(df, target_column, threshold):
    """

    Convert continuous target to binary based on a threshold.
    
    Parameters:
    df (pd.DataFrame): The DataFrame with features and target column
    target_column (str): The name of the target column
    threshold (float): The threshold for categorizing the target
    
    Returns:
    pd.DataFrame: DataFrame with binary target
    """
    df[target_column] = (df[target_column] > threshold).astype(int)
    return df

# Apply categorization
threshold = data['Readmission_Rate'].median()  # Example threshold
data = categorize_target(data, 'Readmission_Rate', threshold)

# Apply Logistic Regression (same as previous code)
apply_logistic_regression(data, 'Readmission_Rate')
# Out:
# Logistic Regression Model Evaluation:
# Accuracy: 0.5133
# ROC AUC: 0.5258
# Confusion Matrix:
# [[66 93]
#  [53 88]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.42      0.47       159
#            1       0.49      0.62      0.55       141
#
#     accuracy                           0.51       300
#    macro avg       0.52      0.52      0.51       300
# weighted avg       0.52      0.51      0.51       300
# Hyperparameter Tuning Results:
# Best Parameters: {'C': 0.1, 'solver': 'liblinear'}
# Best Cross-Validation Score: 0.5029

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

def apply_decision_tree_regression(df, target_column):
    """
    Applies Decision Tree Regression to the DataFrame and evaluates the model.
    
    Parameters:
    df (pd.DataFrame): The DataFrame with features and target column
    target_column (str): The name of the target column
    
    Returns:
    None
    """
    # Copy the DataFrame to avoid modifying the original data
    df = df.copy()
    
    # Separate features and target
    X = df.drop(columns=[target_column])
    y = df[target_column]
    
    # Encode categorical variables
    X = pd.get_dummies(X, drop_first=True)
    
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    
    # Initialize and train the Decision Tree model
    model = DecisionTreeRegressor(random_state=42)
    model.fit(X_train, y_train)
    
    # Make predictions
    y_pred = model.predict(X_test)
    
    # Evaluate the model
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    print("\nDecision Tree Regression Model Evaluation:")
    print(f"Mean Squared Error: {mse:.4f}")
    print(f"R^2 Score: {r2:.4f}")
    
    # Plot the Decision Tree
    plt.figure(figsize=(20, 10))
    plot_tree(model, filled=True, feature_names=X.columns)
    plt.title('Decision Tree Visualization')
    plt.show()

# %%
# Load the data
file_path = 'thesis/healthcare_data.csv'
data = pd.read_csv(file_path)

# Handle missing values (assuming the function is defined as before)
data = handle_missing_values(data)

# Display basic information about the dataset
print("Data Overview:")
print(data.info())

# Display the first few rows of the dataset
print("\nFirst few rows of the dataset:")
print(data.head())

# Apply Decision Tree Regression (assuming 'Readmission_Rate' is the target variable)
apply_decision_tree_regression(data, 'Readmission_Rate')
# Out:
# Data Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Patient_ID        1000 non-null   int64
#  1   Age               1000 non-null   int64
#  2   Gender            1000 non-null   object
#  3   Diagnosis_Code    1000 non-null   object
#  4   Treatment_Type    1000 non-null   object
#  5   Admission_Date    1000 non-null   object
#  6   Discharge_Date    1000 non-null   object
#  7   Length_of_Stay    1000 non-null   int64
#  8   Treatment_Cost    1000 non-null   float64
#  9   Readmission_Rate  1000 non-null   float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 78.2+ KB
# None
#
# First few rows of the dataset:
#    Patient_ID  Age  Gender Diagnosis_Code Treatment_Type Admission_Date  \
# 0           1   69    Male           D001        Surgery     2022-01-01
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

def apply_random_forest_regression(df, target_column):
    """
    Applies Random Forest Regression to the DataFrame and evaluates the model.
    
    Parameters:
    df (pd.DataFrame): The DataFrame with features and target column
    target_column (str): The name of the target column
    
    Returns:
    None
    """
    # Copy the DataFrame to avoid modifying the original data
    df = df.copy()
    
    # Separate features and target
    X = df.drop(columns=[target_column])
    y = df[target_column]
    
    # Encode categorical variables
    X = pd.get_dummies(X, drop_first=True)
    
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    
    # Initialize and train the Random Forest model
    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, y_train)
    
    # Make predictions
    y_pred = model.predict(X_test)
    
    # Evaluate the model
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    print("\nRandom Forest Regression Model Evaluation:")
    print(f"Mean Squared Error: {mse:.4f}")
    print(f"R^2 Score: {r2:.4f}")
    
    # Plot feature importances
    feature_importances = pd.Series(model.feature_importances_, index=X.columns).sort_values(ascending=False)
    plt.figure(figsize=(12, 8))
    sns.barplot(x=feature_importances, y=feature_importances.index)
    plt.title('Feature Importances in Random Forest')
    plt.xlabel('Importance')
    plt.ylabel('Feature')
    plt.show()

# %%
# Load the data
file_path = 'thesis/healthcare_data.csv'
data = pd.read_csv(file_path)

# Handle missing values (assuming the function is defined as before)
data = handle_missing_values(data)

# Display basic information about the dataset
print("Data Overview:")
print(data.info())

# Display the first few rows of the dataset
print("\nFirst few rows of the dataset:")
print(data.head())

# Apply Random Forest Regression (assuming 'Readmission_Rate' is the target variable)
apply_random_forest_regression(data, 'Readmission_Rate')
# Out:
# Data Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Patient_ID        1000 non-null   int64
#  1   Age               1000 non-null   int64
#  2   Gender            1000 non-null   object
#  3   Diagnosis_Code    1000 non-null   object
#  4   Treatment_Type    1000 non-null   object
#  5   Admission_Date    1000 non-null   object
#  6   Discharge_Date    1000 non-null   object
#  7   Length_of_Stay    1000 non-null   int64
#  8   Treatment_Cost    1000 non-null   float64
#  9   Readmission_Rate  1000 non-null   float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 78.2+ KB
# None
#
# First few rows of the dataset:
#    Patient_ID  Age  Gender Diagnosis_Code Treatment_Type Admission_Date  \
# 0           1   69    Male           D001        Surgery     2022-01-01
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score

def preprocess_data(df, target_column):
    """
    Preprocesses the data by handling missing values, encoding categorical variables,
    and scaling features.
    
    Parameters:
    df (pd.DataFrame): The DataFrame with features and target column
    target_column (str): The name of the target column
    
    Returns:
    X_train, X_test, y_train, y_test: Split and preprocessed data
    """
    # Copy the DataFrame to avoid modifying the original data
    df = df.copy()
    
    # Handle missing values (using mean imputation here)
    df.fillna(df.mean(numeric_only=True), inplace=True)
    
    # Separate features and target
    X = df.drop(columns=[target_column])
    y = df[target_column]
    
    # Encode categorical variables
    X = pd.get_dummies(X, drop_first=True)
    
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    
    # Standardize features
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    
    return X_train, X_test, y_train, y_test

def apply_svm_regression(df, target_column):
    """
    Applies Support Vector Machine Regression to the DataFrame and evaluates the model.
    
    Parameters:
    df (pd.DataFrame): The DataFrame with features and target column
    target_column (str): The name of the target column
    
    Returns:
    None
    """
    # Preprocess the data
    X_train, X_test, y_train, y_test = preprocess_data(df, target_column)
    
    # Initialize and train the Support Vector Machine model
    model = SVR(kernel='rbf', C=100, gamma='scale')
    model.fit(X_train, y_train)
    
    # Make predictions
    y_pred = model.predict(X_test)
    
    # Evaluate the model
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    print("\nSupport Vector Machine Regression Model Evaluation:")
    print(f"Mean Squared Error: {mse:.4f}")
    print(f"R^2 Score: {r2:.4f}")
    
    # Plot predictions vs actual values
    plt.figure(figsize=(10, 6))
    plt.scatter(y_test, y_pred, alpha=0.7)
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title('Support Vector Machine Regression: Predictions vs Actual')
    plt.show()
    
    # Additional visualization of residuals
    residuals = y_test - y_pred
    plt.figure(figsize=(10, 6))
    sns.histplot(residuals, kde=True)
    plt.title('Residuals Distribution')
    plt.xlabel('Residuals')
    plt.ylabel('Frequency')
    plt.show()
    
    # Feature importances are not directly available in SVM
    print("\nNote: Support Vector Machines do not provide feature importances directly.")

# %%
def main():
    # Load the data
    file_path = 'thesis/healthcare_data.csv'
    data = pd.read_csv(file_path)
    
    # Display basic information about the dataset
    print("Data Overview:")
    print(data.info())
    
    # Display the first few rows of the dataset
    print("\nFirst few rows of the dataset:")
    print(data.head())
    
    # Apply SVM Regression (assuming 'Readmission_Rate' is the target variable)
    apply_svm_regression(data, 'Readmission_Rate')

if __name__ == "__main__":
    main()
# Out:
# Data Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Patient_ID        1000 non-null   int64
#  1   Age               1000 non-null   int64
#  2   Gender            1000 non-null   object
#  3   Diagnosis_Code    1000 non-null   object
#  4   Treatment_Type    1000 non-null   object
#  5   Admission_Date    1000 non-null   object
#  6   Discharge_Date    1000 non-null   object
#  7   Length_of_Stay    1000 non-null   int64
#  8   Treatment_Cost    1000 non-null   float64
#  9   Readmission_Rate  1000 non-null   float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 78.2+ KB
# None
#
# First few rows of the dataset:
#    Patient_ID  Age  Gender Diagnosis_Code Treatment_Type Admission_Date  \
# 0           1   69    Male           D001        Surgery     2022-01-01
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

def preprocess_data(df, target_column):
    """
    Preprocesses the data by handling missing values, encoding categorical variables,
    and scaling features.
    
    Parameters:
    df (pd.DataFrame): The DataFrame with features and target column
    target_column (str): The name of the target column
    
    Returns:
    X_train, X_test, y_train, y_test: Split and preprocessed data
    """
    # Copy the DataFrame to avoid modifying the original data
    df = df.copy()
    
    # Handle missing values (using mean imputation here)
    df.fillna(df.mean(numeric_only=True), inplace=True)
    
    # Separate features and target
    X = df.drop(columns=[target_column])
    y = df[target_column]
    
    # Encode categorical variables
    X = pd.get_dummies(X, drop_first=True)
    
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    
    # Standardize features
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    
    return X_train, X_test, y_train, y_test
# Out:
# /Users/parasgautam/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
def build_neural_network(input_shape):
    """
    Builds a Neural Network model.
    
    Parameters:
    input_shape (int): Number of input features
    
    Returns:
    model: A compiled Neural Network model
    """
    model = Sequential()
    model.add(Dense(64, input_shape=(input_shape,), activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(32, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(16, activation='relu'))
    model.add(Dense(1, activation='linear'))
    
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error', metrics=['mean_squared_error'])
    
    return model

# %%
def apply_neural_network(df, target_column):
    """
    Applies a Neural Network model to the DataFrame and evaluates it.
    
    Parameters:
    df (pd.DataFrame): The DataFrame with features and target column
    target_column (str): The name of the target column
    
    Returns:
    None
    """
    # Preprocess the data
    X_train, X_test, y_train, y_test = preprocess_data(df, target_column)
    
    # Build and train the Neural Network model
    model = build_neural_network(X_train.shape[1])
    history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=1)
    
    # Evaluate the model
    y_pred = model.predict(X_test).flatten()
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    print("\nNeural Network Model Evaluation:")
    print(f"Mean Squared Error: {mse:.4f}")
    print(f"R^2 Score: {r2:.4f}")
    
    # Plot training & validation loss values
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    
    # Plot predictions vs actual values
    plt.figure(figsize=(10, 6))
    plt.scatter(y_test, y_pred, alpha=0.7)
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title('Neural Network Regression: Predictions vs Actual')
    plt.show()
    
    # Additional visualization of residuals
    residuals = y_test - y_pred
    plt.figure(figsize=(10, 6))
    sns.histplot(residuals, kde=True)
    plt.title('Residuals Distribution')
    plt.xlabel('Residuals')
    plt.ylabel('Frequency')
    plt.show()

# %%
def main():
    # Load the data
    file_path = 'thesis/healthcare_data.csv'
    data = pd.read_csv(file_path)
    
    # Display basic information about the dataset
    print("Data Overview:")
    print(data.info())
    
    # Display the first few rows of the dataset
    print("\nFirst few rows of the dataset:")
    print(data.head())
    
    # Apply Neural Network Regression (assuming 'Readmission_Rate' is the target variable)
    apply_neural_network(data, 'Readmission_Rate')

if __name__ == "__main__":
    main()
# Out:
# Data Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Patient_ID        1000 non-null   int64
#  1   Age               1000 non-null   int64
#  2   Gender            1000 non-null   object
#  3   Diagnosis_Code    1000 non-null   object
#  4   Treatment_Type    1000 non-null   object
#  5   Admission_Date    1000 non-null   object
#  6   Discharge_Date    1000 non-null   object
#  7   Length_of_Stay    1000 non-null   int64
#  8   Treatment_Cost    1000 non-null   float64
#  9   Readmission_Rate  1000 non-null   float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 78.2+ KB
# None
#
# First few rows of the dataset:
#    Patient_ID  Age  Gender Diagnosis_Code Treatment_Type Admission_Date  \
# 0           1   69    Male           D001        Surgery     2022-01-01
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

def preprocess_data(df, target_column):
    """
    Preprocesses the data by handling missing values, encoding categorical variables,
    and scaling features.
    
    Parameters:
    df (pd.DataFrame): The DataFrame with features and target column
    target_column (str): The name of the target column
    
    Returns:
    X_train, X_test, y_train, y_test: Split and preprocessed data
    """
    # Copy the DataFrame to avoid modifying the original data
    df = df.copy()
    
    # Handle missing values (using mean imputation here)
    df.fillna(df.mean(numeric_only=True), inplace=True)
    
    # Separate features and target
    X = df.drop(columns=[target_column])
    y = df[target_column]
    
    # Encode categorical variables
    X = pd.get_dummies(X, drop_first=True)
    
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    
    # Standardize features
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    
    return X_train, X_test, y_train, y_test

# %%
def apply_linear_regression(df, target_column):
    """
    Applies Linear Regression model to the DataFrame and evaluates it.
    
    Parameters:
    df (pd.DataFrame): The DataFrame with features and target column
    target_column (str): The name of the target column
    
    Returns:
    None
    """
    # Preprocess the data
    X_train, X_test, y_train, y_test = preprocess_data(df, target_column)
    
    # Initialize and train the Linear Regression model
    model = LinearRegression()
    model.fit(X_train, y_train)
    
    # Make predictions
    y_pred = model.predict(X_test)
    
    # Evaluate the model
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    print("\nLinear Regression Model Evaluation:")
    print(f"Mean Squared Error: {mse:.4f}")
    print(f"R^2 Score: {r2:.4f}")
    
    # Plot predictions vs actual values
    plt.figure(figsize=(10, 6))
    plt.scatter(y_test, y_pred, alpha=0.7)
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title('Linear Regression: Predictions vs Actual')
    plt.show()
    
    # Plot residuals
    residuals = y_test - y_pred
    plt.figure(figsize=(10, 6))
    sns.histplot(residuals, kde=True)
    plt.title('Residuals Distribution')
    plt.xlabel('Residuals')
    plt.ylabel('Frequency')
    plt.show()

# %%
def main():
    # Load the data
    file_path = 'healthcare_data.csv'
    data = pd.read_csv(file_path)
    
    # Display basic information about the dataset
    print("Data Overview:")
    print(data.info())
    
    # Display the first few rows of the dataset
    print("\nFirst few rows of the dataset:")
    print(data.head())
    
    # Apply Linear Regression (assuming 'Readmission_Rate' is the target variable)
    apply_linear_regression(data, 'Readmission_Rate')

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

def preprocess_data(df, target_column):
    """
    Preprocesses the data by handling missing values, encoding categorical variables,
    and scaling features.
    
    Parameters:
    df (pd.DataFrame): The DataFrame with features and target column
    target_column (str): The name of the target column
    
    Returns:
    X_train, X_test, y_train, y_test: Split and preprocessed data
    """
    # Copy the DataFrame to avoid modifying the original data
    df = df.copy()
    
    # Handle missing values (using mean imputation here)
    df.fillna(df.mean(numeric_only=True), inplace=True)
    
    # Separate features and target
    X = df.drop(columns=[target_column])
    y = df[target_column]
    
    # Encode categorical variables
    X = pd.get_dummies(X, drop_first=True)
    
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    
    # Standardize features
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    
    return X_train, X_test, y_train, y_test

# %%
def apply_linear_regression(df, target_column):
    """
    Applies Linear Regression model to the DataFrame and evaluates it.
    
    Parameters:
    df (pd.DataFrame): The DataFrame with features and target column
    target_column (str): The name of the target column
    
    Returns:
    None
    """
    # Preprocess the data
    X_train, X_test, y_train, y_test = preprocess_data(df, target_column)
    
    # Initialize and train the Linear Regression model
    model = LinearRegression()
    model.fit(X_train, y_train)
    
    # Make predictions
    y_pred = model.predict(X_test)
    
    # Evaluate the model
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    print("\nLinear Regression Model Evaluation:")
    print(f"Mean Squared Error: {mse:.4f}")
    print(f"R^2 Score: {r2:.4f}")
    
    # Plot predictions vs actual values
    plt.figure(figsize=(10, 6))
    plt.scatter(y_test, y_pred, alpha=0.7)
    plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.title('Linear Regression: Predictions vs Actual')
    plt.show()
    
    # Plot residuals
    residuals = y_test - y_pred
    plt.figure(figsize=(10, 6))
    sns.histplot(residuals, kde=True)
    plt.title('Residuals Distribution')
    plt.xlabel('Residuals')
    plt.ylabel('Frequency')
    plt.show()

# %%
def main():
    # Load the data
    file_path = 'thesis/healthcare_data.csv'
    data = pd.read_csv(file_path)
    
    # Display basic information about the dataset
    print("Data Overview:")
    print(data.info())
    
    # Display the first few rows of the dataset
    print("\nFirst few rows of the dataset:")
    print(data.head())
    
    # Apply Linear Regression (assuming 'Readmission_Rate' is the target variable)
    apply_linear_regression(data, 'Readmission_Rate')

if __name__ == "__main__":
    main()
# Out:
# Data Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Patient_ID        1000 non-null   int64
#  1   Age               1000 non-null   int64
#  2   Gender            1000 non-null   object
#  3   Diagnosis_Code    1000 non-null   object
#  4   Treatment_Type    1000 non-null   object
#  5   Admission_Date    1000 non-null   object
#  6   Discharge_Date    1000 non-null   object
#  7   Length_of_Stay    1000 non-null   int64
#  8   Treatment_Cost    1000 non-null   float64
#  9   Readmission_Rate  1000 non-null   float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 78.2+ KB
# None
#
# First few rows of the dataset:
#    Patient_ID  Age  Gender Diagnosis_Code Treatment_Type Admission_Date  \
# 0           1   69    Male           D001        Surgery     2022-01-01
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA

def preprocess_data(df):
    """
    Preprocesses the data by handling missing values, encoding categorical variables, and scaling features.
    
    Parameters:
    df (pd.DataFrame): The DataFrame with features
    
    Returns:
    X_scaled: Scaled features
    """
    # Copy the DataFrame to avoid modifying the original data
    df = df.copy()
    
    # Handle missing values (using mean imputation for numeric columns)
    df.fillna(df.mean(numeric_only=True), inplace=True)
    
    # Encode categorical features
    categorical_cols = df.select_dtypes(include=['object']).columns
    for col in categorical_cols:
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col])
    
    # Separate features
    X = df
    
    # Standardize features
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    return X_scaled

# %%
def apply_kmeans(df, n_clusters=3):
    """
    Applies K-Means Clustering to the DataFrame and evaluates it.
    
    Parameters:
    df (pd.DataFrame): The DataFrame with features
    n_clusters (int): Number of clusters for K-Means
    
    Returns:
    None
    """
    # Preprocess the data
    X_scaled = preprocess_data(df)
    
    # Initialize KMeans
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    
    # Fit KMeans
    kmeans.fit(X_scaled)
    
    # Predict cluster labels
    labels = kmeans.predict(X_scaled)
    
    # Calculate silhouette score
    silhouette_avg = silhouette_score(X_scaled, labels)
    print(f"Silhouette Score: {silhouette_avg:.4f}")
    
    # Add cluster labels to original DataFrame
    df['Cluster'] = labels
    
    # Plot clusters in 2D using PCA for visualization
    pca = PCA(n_components=2)
    X_pca = pca.fit_transform(X_scaled)
    
    plt.figure(figsize=(12, 8))
    plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels, cmap='viridis', alpha=0.6)
    plt.title('K-Means Clustering (PCA-reduced data)')
    plt.xlabel('Principal Component 1')
    plt.ylabel('Principal Component 2')
    plt.colorbar(label='Cluster Label')
    plt.show()

    

    # Plot the cluster centers
    centers_pca = pca.transform(kmeans.cluster_centers_)
    plt.figure(figsize=(12, 8))
    plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels, cmap='viridis', alpha=0.6)
    plt.scatter(centers_pca[:, 0], centers_pca[:, 1], c='red', marker='X', s=200, label='Centroids')
    plt.title('K-Means Clustering with Cluster Centers')
    plt.xlabel('Principal Component 1')
    plt.ylabel('Principal Component 2')
    plt.legend()
    plt.show()

# %%
def main():
    # Load the data
    file_path = 'thesis/healthcare_data.csv'
    data = pd.read_csv(file_path)
    
    # Display basic information about the dataset
    print("Data Overview:")
    print(data.info())
    
    # Display the first few rows of the dataset
    print("\nFirst few rows of the dataset:")
    print(data.head())
    
    # Apply K-Means Clustering
    apply_kmeans(data, n_clusters=3)

if __name__ == "__main__":
    main()
# Out:
# Data Overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Patient_ID        1000 non-null   int64
#  1   Age               1000 non-null   int64
#  2   Gender            1000 non-null   object
#  3   Diagnosis_Code    1000 non-null   object
#  4   Treatment_Type    1000 non-null   object
#  5   Admission_Date    1000 non-null   object
#  6   Discharge_Date    1000 non-null   object
#  7   Length_of_Stay    1000 non-null   int64
#  8   Treatment_Cost    1000 non-null   float64
#  9   Readmission_Rate  1000 non-null   float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 78.2+ KB
# None
#
# First few rows of the dataset:
#    Patient_ID  Age  Gender Diagnosis_Code Treatment_Type Admission_Date  \
# 0           1   69    Male           D001        Surgery     2022-01-01
# ...
